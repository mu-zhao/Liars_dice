# %%
import numpy as np
from common import PlatForm as PF 
from strategies.epsilon_intelligence.epsilon_intelligence import EpsilonIntelligence as EI
from strategies.zero_intelligence.zero_intelligence import ZeroIntelligence as ZI
from strategies.human_player.player import HumanPlayer as HP
from strategies.naive_intelligence.naive_intelligence import NaiveIntelligence as NI
player=HP()
L=[NI(simulation_time_limit=0.2,aggresive=0.8,simple_minded=False,response_principle=0),ZI(0.5,0.5),player,ZI(0.5,0.5)]
Game=PF(3,L,call_level=0.3,bluff=0.05,trainning=False)
Game.play()
# Out:
# Turn 0, Players Dice [3 3 3 3] Player 0 bid [4, 5]
# Turn 1, Players Dice [3 3 3 3] Player 1 bid [5 2]
# current players in game dice: [3 3 3 3]
# Your dice result[1 0 2 0 0 0]
# Player2, Your bid?
# 5,4
# Turn 2, Players Dice [3 3 3 3] Player 2 bid [5, 4]
# Turn 3, Players Dice [3 3 3 3] Player 3 bid [6 1]
# palyer 0 call liar
# player 0 outcome [0 1 0 0 0 2]
# player 1 outcome [0 0 1 1 0 1]
# player 2 outcome [1 0 2 0 0 0]
# player 3 outcome [0 2 0 0 1 0]
# total outcome [1 3 3 1 1 3]
# There are 4 1s
# palyer 0 good call, player 3 loses one dice
# ------------------------------------------------------------------
# A new round of game
# Turn 0, Players Dice [3 3 3 2] Player 3 bid [4, 5]
# Turn 1, Players Dice [3 3 3 2] Player 0 bid [5, 1]
# palyer 1 call liar
# player 0 outcome [0 2 0 1 0 0]
# player 1 outcome [0 1 0 1 1 0]
# player 2 outcome [0 2 0 0 0 1]
# player 3 outcome [1 0 0 0 0 1]
# total outcome [1 5 0 2 1 2]
# There are 6 1s
# player 1 bad call, player 1 loses one dice
# ------------------------------------------------------------------
# A new round of game
# Turn 0, Players Dice [3 2 3 2] Player 1 bid [3, 4]
# current players in game dice: [3 2 3 2]
# Your dice result[1 0 0 1 1 0]
# Player2, Your bid?
# 4,4
# Turn 1, Players Dice [3 2 3 2] Player 2 bid [4, 4]
# palyer 3 call liar
# player 0 outcome [0 0 1 0 0 2]
# player 1 outcome [0 0 0 0 2 0]
# player 2 outcome [1 0 0 1 1 0]
# player 3 outcome [0 1 0 0 1 0]
# total outcome [1 1 1 1 4 2]
# There are 5 4s
# player 3 bad call, player 3 loses one dice
# ------------------------------------------------------------------
# A new round of game
# Turn 0, Players Dice [3 2 3 1] Player 3 bid [2, 4]
# Turn 1, Players Dice [3 2 3 1] Player 0 bid [3, 3]
# Turn 2, Players Dice [3 2 3 1] Player 1 bid [3 4]
# current players in game dice: [3 2 3 1]
# Your dice result[1 0 1 0 1 0]
# Player2, Your bid?
# 4,4
# Turn 3, Players Dice [3 2 3 1] Player 2 bid [4, 4]
# Turn 4, Players Dice [3 2 3 1] Player 3 bid [4 5]
# palyer 0 call liar
# player 0 outcome [0 0 0 1 2 0]
# player 1 outcome [0 0 0 0 1 1]
# player 2 outcome [1 0 1 0 1 0]
# player 3 outcome [1 0 0 0 0 0]
# total outcome [2 0 1 1 4 1]
# There are 3 5s
# palyer 0 good call, player 3 loses one dice
# ------------------------------------------------------------------
# A new round of game
# Turn 0, Players Dice [3 2 3 0] Player 0 bid [3, 5]
# Turn 1, Players Dice [3 2 3 0] Player 1 bid [4 3]
# current players in game dice: [3 2 3 0]
# Your dice result[0 0 0 2 0 1]
# Player2, Your bid?
# 4,5
# Turn 2, Players Dice [3 2 3 0] Player 2 bid [4, 5]
# palyer 0 call spot-on
# player 0 outcome [0 0 0 0 1 2]
# player 1 outcome [1 0 0 1 0 0]
# player 2 outcome [0 0 0 2 0 1]
# total outcome [1 0 0 3 1 3]
# There are 4 5s
# good call,everyone except player 0 loses one dice
# ------------------------------------------------------------------
# A new round of game
# Turn 0, Players Dice [3 1 2 0] Player 0 bid [2, 5]
# Turn 1, Players Dice [3 1 2 0] Player 1 bid [3 4]
# current players in game dice: [3 1 2 0]
# Your dice result[0 0 0 1 0 1]
# Player2, Your bid?
# 0
# palyer 2 call liar
# player 0 outcome [1 0 0 0 1 1]
# player 1 outcome [0 0 0 0 1 0]
# player 2 outcome [0 0 0 1 0 1]
# total outcome [1 0 0 1 2 2]
# There are 3 4s
# player 2 bad call, player 2 loses one dice
# ------------------------------------------------------------------
# A new round of game
# current players in game dice: [3 1 1 0]
# Your dice result[0 0 0 0 1 0]
# Player2, Your bid?
# 2,4
# Turn 0, Players Dice [3 1 1 0] Player 2 bid [2, 4]
# Turn 1, Players Dice [3 1 1 0] Player 0 bid [2, 5]
# Turn 2, Players Dice [3 1 1 0] Player 1 bid [3 1]
# current players in game dice: [3 1 1 0]
# Your dice result[0 0 0 0 1 0]
# Player2, Your bid?
# 0
# palyer 2 call liar
# player 0 outcome [0 0 1 0 2 0]
# player 1 outcome [0 1 0 0 0 0]
# player 2 outcome [0 0 0 0 1 0]
# total outcome [0 1 1 0 3 0]
# There are 1 1s
# palyer 2 good call, player 1 loses one dice
# ------------------------------------------------------------------
# A new round of game
# current players in game dice: [3 0 1 0]
# Your dice result[0 1 0 0 0 0]
# Player2, Your bid?
# 1,5
# Turn 0, Players Dice [3 0 1 0] Player 2 bid [1, 5]
# Turn 1, Players Dice [3 0 1 0] Player 0 bid [2, 5]
# current players in game dice: [3 0 1 0]
# Your dice result[0 1 0 0 0 0]
# Player2, Your bid?
# 0
# palyer 2 call liar
# player 0 outcome [0 0 0 1 0 2]
# player 2 outcome [0 1 0 0 0 0]
# total outcome [0 1 0 1 0 2]
# There are 2 5s
# player 2 bad call, player 2 loses one dice
# ------------------------------------------------------------------
# A new round of game
# 0
# Game Over

# %% [markdown]
# # player 0 is naive_intelligence, player 2 is human, the other two players are zero_intelligence
