# %%
from strategies.common import PlatForm as PF 
from strategies.epsilon_intelligence import EpsilonIntelligence as EI
from strategies.zero_intelligence import ZeroIntelligence as ZI
from strategies.player import HumanPlayer as HP
from strategies.naive_intelligence import NaiveIntelligence as NI
player=HP()
L=[NI(simulation_time_limit=0.3,aggresive=0.9,simple_minded=False,response_principle=0)]
for i in range(8):
    L.append(player)
Game=PF(3,L,call_level=1/3,bluff=0.05,advisor=0,savage_settle=True,trainning=False)
Game.first_advisor()
# Out:
# Player 0 Your rollout
# 0,0,2,1,0,0
#                                       response dice lost relative power error
# call liar                                  NaN       NaN            NaN   NaN
# call spot on                               NaN       NaN            NaN   NaN
# suggestion:reasonalbe call assumption  [10, 1]        -0         11.608     0
# suggestion: naive call assumption       [6, 1]        -0         11.608     0
# suggestion: simple call assumption      [7, 2]        -0         11.608     0
# joint suggestion                        [7, 2]       NaN            NaN   NaN
# Advisor Suggestion:
# [7, 2]
# Accept?
# y
# Yes Sir!
# Turn 0, Players Dice [3 3 3 3 3 3 3 3 3] Player 0 bid [7, 2]
# current players in game dice: [3 3 3 3 3 3 3 3 3]
# Player1, Your bid?
# 8,1
# Turn 1, Players Dice [3 3 3 3 3 3 3 3 3] Player 1 bid [8, 1]
# current players in game dice: [3 3 3 3 3 3 3 3 3]
# Player2, Your bid?
# 9,1
# Turn 2, Players Dice [3 3 3 3 3 3 3 3 3] Player 2 bid [9, 1]
# current players in game dice: [3 3 3 3 3 3 3 3 3]
# Player3, Your bid?
# 0
# luck?
# n
# A new round of game
# A new round of game
# A new round of game
# A new round of game
# A new round of game
# A new round of game
# A new round of game
# A new round of game
# Player 0 Your rollout
# 0,1,0,0,2,0
# current players in game dice: [3 3 3 2 3 3 3 3 3]
# Player3, Your bid?
# 6,4
# Turn 0, Players Dice [3 3 3 2 3 3 3 3 3] Player 3 bid [6, 4]
# current players in game dice: [3 3 3 2 3 3 3 3 3]
# Player4, Your bid?
# 7,2
# Turn 1, Players Dice [3 3 3 2 3 3 3 3 3] Player 4 bid [7, 2]
# current players in game dice: [3 3 3 2 3 3 3 3 3]
# Player5, Your bid?
# 8,7
# Denomination out of range
#
# current players in game dice: [3 3 3 2 3 3 3 3 3]
# Player5, Your bid?
# 9,0
# Turn 2, Players Dice [3 3 3 2 3 3 3 3 3] Player 5 bid [9, 0]
# current players in game dice: [3 3 3 2 3 3 3 3 3]
# Player6, Your bid?
# 12,1
# Your bid [12, 1] is not large enough
#
# current players in game dice: [3 3 3 2 3 3 3 3 3]
# Player6, Your bid?
# 14,1
# Your bid [14, 1] is not large enough
#
# current players in game dice: [3 3 3 2 3 3 3 3 3]
# Player6, Your bid?
# 12,0
# Turn 3, Players Dice [3 3 3 2 3 3 3 3 3] Player 6 bid [12, 0]
# current players in game dice: [3 3 3 2 3 3 3 3 3]
# Player7, Your bid?
# 0
# luck?
# n
# A new round of game
# A new round of game
# A new round of game
# A new round of game
# A new round of game
# A new round of game
# A new round of game
# A new round of game
# Player 0 Your rollout
# 0,0,0,1,2,0
# current players in game dice: [3 3 3 2 3 3 3 2 3]
# Player7, Your bid?
# 3,0
# Turn 0, Players Dice [3 3 3 2 3 3 3 2 3] Player 7 bid [3, 0]
# current players in game dice: [3 3 3 2 3 3 3 2 3]
# Player8, Your bid?
# 5,4
# Your bid [5, 4] is not large enough
#
# current players in game dice: [3 3 3 2 3 3 3 2 3]
# Player8, Your bid?
# 6,5
# Turn 1, Players Dice [3 3 3 2 3 3 3 2 3] Player 8 bid [6, 5]
#                                       response dice lost relative power error
# call liar                                  NaN -0.790916        8.86374   NaN
# call spot on                               NaN -0.842495        9.61776   NaN
# suggestion:reasonalbe call assumption   [9, 2]        -0        12.7291     0
# suggestion: naive call assumption       [8, 4]        -0        12.7305     0
# suggestion: simple call assumption      [8, 5]        -0        12.7373     0
# joint suggestion                        [8, 4]       NaN            NaN   NaN
# Advisor Suggestion:
# [8, 4]
# Accept?
# y
# Yes Sir!
# Turn 2, Players Dice [3 3 3 2 3 3 3 2 3] Player 0 bid [8, 4]
# current players in game dice: [3 3 3 2 3 3 3 2 3]
# Player1, Your bid?
# 8,5
# Turn 3, Players Dice [3 3 3 2 3 3 3 2 3] Player 1 bid [8, 5]
# current players in game dice: [3 3 3 2 3 3 3 2 3]
# Player2, Your bid?
# 5,0
# Turn 4, Players Dice [3 3 3 2 3 3 3 2 3] Player 2 bid [5, 0]
# current players in game dice: [3 3 3 2 3 3 3 2 3]
# Player3, Your bid?
# 6,0
# Turn 5, Players Dice [3 3 3 2 3 3 3 2 3] Player 3 bid [6, 0]
# current players in game dice: [3 3 3 2 3 3 3 2 3]
# Player4, Your bid?
# 7,0
# Turn 6, Players Dice [3 3 3 2 3 3 3 2 3] Player 4 bid [7, 0]
# current players in game dice: [3 3 3 2 3 3 3 2 3]
# Player5, Your bid?
# 14,2
# Turn 7, Players Dice [3 3 3 2 3 3 3 2 3] Player 5 bid [14, 2]
# current players in game dice: [3 3 3 2 3 3 3 2 3]
# Player6, Your bid?
# 14,4
# Turn 8, Players Dice [3 3 3 2 3 3 3 2 3] Player 6 bid [14, 4]
# current players in game dice: [3 3 3 2 3 3 3 2 3]
# Player7, Your bid?
# 8,0
# Turn 9, Players Dice [3 3 3 2 3 3 3 2 3] Player 7 bid [8, 0]
# current players in game dice: [3 3 3 2 3 3 3 2 3]
# Player8, Your bid?
# 0
# luck?
# y
# A new round of game
# A new round of game
# A new round of game
# A new round of game
# A new round of game
# A new round of game
# A new round of game
# A new round of game
# Player 0 Your rollout
# 0,0,0,1,2,0
# current players in game dice: [3 3 3 2 3 3 3 1 3]
# Player7, Your bid?
# 4,5
# Turn 0, Players Dice [3 3 3 2 3 3 3 1 3] Player 7 bid [4, 5]
# current players in game dice: [3 3 3 2 3 3 3 1 3]
# Player8, Your bid?
# 5,1
# Turn 1, Players Dice [3 3 3 2 3 3 3 1 3] Player 8 bid [5, 1]
#                                       response dice lost relative power error
# call liar                                  NaN -0.875771        8.83812   NaN
# call spot on                               NaN -0.870641        9.74916   NaN
# suggestion:reasonalbe call assumption   [9, 4]        -0        13.3279     0
# suggestion: naive call assumption       [6, 5]        -0        13.3287     0
# suggestion: simple call assumption      [5, 0]        -0        13.3284     0
# joint suggestion                        [6, 5]       NaN            NaN   NaN
# Advisor Suggestion:
# [6, 5]
