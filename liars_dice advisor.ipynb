# %%
from strategies.common import PlatForm as PF 
from strategies.epsilon_intelligence import EpsilonIntelligence as EI
from strategies.zero_intelligence import ZeroIntelligence as ZI
from strategies.player import HumanPlayer as HP
from strategies.naive_intelligence import NaiveIntelligence as NI
player=HP()
L=[]
for i in range(1):
    L.append(player)
L+=[NI(simulation_time_limit=0.01,aggresive=0.9,simple_minded=False,response_principle=0)]
Game=PF(5,L,call_level=1/3,bluff=0.05,advisor=1,savage_settle=True,trainning=False)
Game.first_advisor()
# Out:
# Player 1 Your rollout
# 4,0,0,0,1,0
# current players in game dice: [5 5]
# Player0, Your bid?
# 3,5
# Turn 0, Players Dice [5 5] Player 0 bid [3, 5]
# [2, 0] 56.65459169008369 -0.0 0.04323970346008157
# [4, 0] 56.6545916900837 -0.0 0.1994784867264304
# [2, 0] 56.65459169008369 -0.0 0.04139133939148167
#                                       response dice lost relative power  \
# call liar                                  NaN        -1             -1
# call spot on                               NaN   43.3454        43.3454
# suggestion:reasonalbe call assumption   [2, 0]        -0        56.6546
# suggestion: naive call assumption       [4, 0]        -0        56.6546
# suggestion: simple call assumption      [2, 0]        -0        56.6546
# joint suggestion                        [2, 0]       NaN            NaN
#
#                                            error
# call liar                                    NaN
# call spot on                                 NaN
# suggestion:reasonalbe call assumption  0.0432397
# suggestion: naive call assumption       0.199478
# suggestion: simple call assumption     0.0413913
# joint suggestion                             NaN
# Advisor Suggestion:
# [2, 0]
# Accept?
# 4,0
# Player1, Your bid?
# 8,1
# Yes Mr. Admiral!
# Turn 1, Players Dice [5 5] Player 1 bid [2, 0]
# current players in game dice: [5 5]
# Player0, Your bid?
# 3,0
# Turn 2, Players Dice [5 5] Player 0 bid [3, 0]
# [4, 0] 56.65459169008369 -0.0 0.03532049841522617
# [6, 4] 56.6545916900837 -0.0 0.1787436222592133
# [4, 0] 56.65459169008369 -0.0 0.035234667307686277
#                                       response dice lost relative power  \
# call liar                                  NaN        -1             -1
# call spot on                               NaN   43.3454        43.3454
# suggestion:reasonalbe call assumption   [4, 0]        -0        56.6546
# suggestion: naive call assumption       [6, 4]        -0        56.6546
# suggestion: simple call assumption      [4, 0]        -0        56.6546
# joint suggestion                        [4, 0]       NaN            NaN
#
#                                            error
# call liar                                    NaN
# call spot on                                 NaN
# suggestion:reasonalbe call assumption  0.0353205
# suggestion: naive call assumption       0.178744
# suggestion: simple call assumption     0.0352347
# joint suggestion                             NaN
# Advisor Suggestion:
# [4, 0]
# Accept?
# y
# Yes Sir!
# Turn 3, Players Dice [5 5] Player 1 bid [4, 0]
# current players in game dice: [5 5]
# Player0, Your bid?
# 8,3
# Turn 4, Players Dice [5 5] Player 0 bid [8, 3]
# [5, 0] 55.86545988494931 -0.059292278315910336 0.02276168640735925
# [6, 0] 56.6545916900837 -0.0 0.0
# [5, 0] 56.65459169008369 -0.0 0.020909885387194425
#                                       response  dice lost relative power  \
# call liar                                  NaN  -0.954483      -0.995906
# call spot on                               NaN    43.9512        43.3999
# suggestion:reasonalbe call assumption   [5, 0] -0.0592923        55.8655
# suggestion: naive call assumption       [6, 0]         -0        56.6546
# suggestion: simple call assumption      [5, 0]         -0        56.6546
# joint suggestion                        [5, 0]        NaN            NaN
#
#                                            error
# call liar                                    NaN
# call spot on                                 NaN
# suggestion:reasonalbe call assumption  0.0227617
# suggestion: naive call assumption              0
# suggestion: simple call assumption     0.0209099
# joint suggestion                             NaN
# Advisor Suggestion:
# [5, 0]
